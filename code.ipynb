# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef

# %%
x=pd.read_csv('C:\\Users\\Aayush Kandpal\\Downloads\\train.csv')
y=pd.read_csv('C:\\Users\\Aayush Kandpal\\Downloads\\train.csv')
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 283 to 748
# Data columns (total 11 columns):
# v.id           900 non-null int64
# on road old    900 non-null int64
# on road now    900 non-null int64
# years          900 non-null int64
# km             900 non-null int64
# rating         900 non-null int64
# condition      900 non-null int64
# economy        900 non-null int64
# top speed      900 non-null int64
# hp             900 non-null int64
# torque         900 non-null int64
# dtypes: int64(11)
# memory usage: 84.4 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 912 to 115
# Data columns (total 11 columns):
# v.id           100 non-null int64
# on road old    100 non-null int64
# on road now    100 non-null int64
# years          100 non-null int64
# km             100 non-null int64
# rating         100 non-null int64
# condition      100 non-null int64
# economy        100 non-null int64
# top speed      100 non-null int64
# hp             100 non-null int64
# torque         100 non-null int64
# dtypes: int64(11)
# memory usage: 9.4 KB

# %%
x_train.head()
# Out:
#      v.id  on road old  on road now  years      km  rating  condition  \
# 954   955       506504       700428      4  105905       3          1
# 65     66       617740       730220      2  121698       1          8
# 918   919       688765       766206      2   93280       3          2
# 354   355       575398       888701      7  103222       2          1
# 946   947       508242       775411      4   60917       1          6
#
#      economy  top speed   hp  torque
# 954       13        160   52     130
# 65        13        156   89      96
# 918       14        145   51      78
# 354        9        198   78      68
# 946       10        151  100      69

# %%
x_test.head()
# Out:
#      v.id  on road old  on road now  years      km  rating  condition  \
# 824   825       512809       861615      3   88429       5          7
# 542   543       516090       894113      4   54562       1          3
# 39     40       669414       825723      4  124136       3          3
# 111   112       600109       884745      7   74321       2          2
# 976   977       678056       863982      5  146214       2          2
#
#      economy  top speed   hp  torque
# 824       14        174   54      85
# 542       11        145   90     115
# 39        10        159   50      90
# 111       12        192  113      95
# 976       14        155   91      94

# %%
x_train.describe()
# Out:
#               v.id    on road old    on road now       years             km  \
# count   900.000000     900.000000     900.000000  900.000000     900.000000
# mean    503.558889  602631.335556  798858.495556    4.558889  100129.296667
# std     291.154619   58552.162636   57234.885866    1.727188   29108.822157
# min       1.000000  500265.000000  700159.000000    2.000000   50324.000000
# 25%     247.750000  548993.750000  750459.000000    3.000000   74202.750000
# 50%     508.500000  603762.500000  797960.500000    5.000000   99330.000000
# 75%     756.250000  653924.000000  847625.750000    6.000000  124821.000000
# max    1000.000000  699714.000000  899797.000000    7.000000  149902.000000
#
#            rating   condition     economy   top speed          hp      torque
# count  900.000000  900.000000  900.000000  900.000000  900.000000  900.000000
# mean     2.991111    5.582222   11.610000  166.761111   84.430000  103.666667
# std      1.401544    2.841555    2.245279   19.482106   20.571982   20.997696
# min      1.000000    1.000000    8.000000  135.000000   50.000000   68.000000
# 25%      2.000000    3.000000   10.000000  150.000000   67.000000   85.000000
# 50%      3.000000    6.000000   12.000000  166.000000   84.000000  104.000000
# 75%      4.000000    8.000000   13.000000  184.000000  102.000000  121.000000
# max      5.000000   10.000000   15.000000  200.000000  120.000000  140.000000

# %%
x_test.describe()
# Out:
#              v.id    on road old    on road now       years           km  \
# count  100.000000     100.000000     100.000000  100.000000     100.0000
# mean   472.970000  592800.840000  801587.510000    4.580000  101580.6300
# std    266.664752   56604.752825   55359.748261    1.652546   29638.6202
# min      7.000000  501908.000000  700018.000000    2.000000   50714.0000
# 25%    268.500000  545160.250000  760137.750000    3.000000   75920.0000
# 50%    448.500000  590915.000000  801488.500000    5.000000  102103.5000
# 75%    664.000000  643109.000000  844001.000000    6.000000  128760.7500
# max    988.000000  699859.000000  899711.000000    7.000000  149529.0000
#
#            rating   condition     economy   top speed          hp     torque
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.00000
# mean     2.960000    5.680000   11.760000  168.080000   85.590000  101.23000
# std      1.420769    2.677554    2.099158   17.493248   20.085723   21.58369
# min      1.000000    1.000000    8.000000  135.000000   50.000000   68.00000
# 25%      2.000000    3.750000   10.000000  155.750000   71.500000   81.00000
# 50%      3.000000    6.000000   12.000000  167.000000   84.000000  100.00000
# 75%      4.000000    8.000000   13.250000  181.250000  104.000000  119.50000
# max      5.000000   10.000000   15.000000  200.000000  120.000000  140.00000

# %%
print ("Skew is:", x_train.price.skew())

plt.hist(x_train.price)
plt.show()
# It can be observed that the data is almost centrally alligned so there is no need of transformation
#Along y is the number of observations
#Along x is the price
# Out:
# Skew is: 0.010610130615221465

# %%
numerical_features = x_train.select_dtypes(include=[np.number])
corr = numerical_features.corr()
print (corr['price'].sort_values(ascending=False)[:], '\n')

# This gives the correlation each feature and the price of the car
# Out:
# price          1.000000
# on road now    0.267294
# on road old    0.237478
# condition      0.103110
# rating         0.045206
# hp             0.031105
# torque         0.007666
# years         -0.007331
# economy       -0.027346
# top speed     -0.033575
# v.id          -0.059933
# km            -0.936504
# Name: price, dtype: float64

# %%
plt.scatter(x_train['km'],x_train['price'])
# Just a visulisation of the worst related feature , that is the km. The graph pretty much sums up the correlation...being the exact opposite of the required visual.

# %%
#tried to visualise the correlation 
sns.heatmap(x_train.corr(), annot = True, vmin=-1, vmax=1, center= 0)
#I dont know why I did this....

# %%
sns.kdeplot(x_train, cmap="Blues", shade=True, shade_lowest=True, )
# this will give you an estimate about the price range in which the houses lie

# %%
x_train=x_train.drop(['price'],axis=1)
y_train=y_train['price']

x_test=x_test.drop(['price'],axis=1)
y_test=y_test['price']

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(reg.intercept_)
#For retrieving the slope:
print(reg.coef_)
# Out:
# -13272.233123741986
# [ 7.95464932e-01  5.04816929e-01  4.99609366e-01 -1.50753551e+03
#  -4.00234661e+00  7.62167600e+01  4.60093650e+03  6.14724697e+01
#  -6.71620430e+00  1.87389582e+01 -3.54872694e+00]

# %%
reg.score(x_test,y_test)
# Out:
# 0.9961195882386958

# %%
reg.score(x_test,y_test)
# Out:
# 0.9961195882386958

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.05, loss = 'ls')

# %%
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.05, loss='ls', max_depth=5,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=400,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
clf.score(x_test,y_test)
# Out:
# 0.994356953382204

# %%
#To retrieve the intercept:
print(reg.intercept_)
#For retrieving the slope:
print(reg.coef_)
# Out:
# -13272.233123741986
# [ 7.95464932e-01  5.04816929e-01  4.99609366e-01 -1.50753551e+03
#  -4.00234661e+00  7.62167600e+01  4.60093650e+03  6.14724697e+01
#  -6.71620430e+00  1.87389582e+01 -3.54872694e+00]

# %%
y_pred=pd.DataFrame(reg.predict(x_test))

print(y_pred)
pd.set_option('display.max_rows', None)
# Out:
#                 0
# 0   351273.395345
# 1   484851.500889
# 2   248560.479633
# 3   434360.617119
# 4   179261.372850
# 5   241238.964064
# 6   303451.800581
# 7   169788.724262
# 8   293353.485382
# 9   156530.851576
# 10  305143.221989
# 11  122911.379648
# 12  467803.552097
# 13   92334.303114
# 14  453721.475325
# 15  284698.701806
# 16  502866.390294
# 17  303997.539051
# 18  278878.032125
# 19  501950.647199
# 20  155285.228691
# 21  287893.123497
# 22  535029.305299
# 23  185853.335990
# 24  177029.445969
# 25  246916.831589
# 26  325273.837372
# 27  320058.579978
# 28  420016.755485
# 29  214066.271224
# 30   26180.339819
# 31  511784.198080
# 32  106306.897453
# 33  117058.215738
# 34  324611.813595
# 35  504337.923528
# 36  349869.553567
# 37  465858.759655
# 38  192362.302100
# 39  311678.161274
# 40  465245.904534
# 41  386984.681476
# 42  184502.646035
# 43  392037.440662
# 44  162033.393016
# 45  222621.206354
# 46  391101.577851
# 47  336830.652801
# 48  306325.246727
# 49  126055.047963
# 50  264303.195902
# 51  249667.715098
# 52  257086.306894
# 53  112782.556207
# 54  273603.118284
# 55  395662.291490
# 56  196808.259983
# 57  365664.114589
# 58  242253.640029
# 59  510177.616561
# 60  453595.864086
# 61  384708.093264
# 62  192402.827832
# 63  335722.002758
# 64  179618.804815
# 65  489539.445375
# 66  497786.243637
# 67  171935.851404
# 68  531735.321240
# 69  349065.265654
# 70  300540.019323
# 71  286261.494000
# 72  455997.894858
# 73  496615.019722
# 74  320238.571077
# 75  328386.887329
# 76  375087.305383
# 77  117138.736691
# 78  429004.452473
# 79  398571.416828
# 80  381806.509689
# 81  239495.406616
# 82  330151.895946
# 83  421253.191853
# 84  183892.537639
# 85  292692.774398
# 86  132662.135590
# 87  408844.786585
# 88  107059.898656
# 89  502922.878514
# 90  195943.637366
# 91  213591.724574
# 92  223512.575637
# 93   98659.658076
# 94  500346.121699
# 95  235235.458084
# 96  113261.596020
# 97   67930.376300
# 98  217187.560220
# 99  128854.852139

# %%
y_pred
# Out:
#                 0
# 0   351273.395345
# 1   484851.500889
# 2   248560.479633
# 3   434360.617119
# 4   179261.372850
# 5   241238.964064
# 6   303451.800581
# 7   169788.724262
# 8   293353.485382
# 9   156530.851576
# 10  305143.221989
# 11  122911.379648
# 12  467803.552097
# 13   92334.303114
# 14  453721.475325
# 15  284698.701806
# 16  502866.390294
# 17  303997.539051
# 18  278878.032125
# 19  501950.647199
# 20  155285.228691
# 21  287893.123497
# 22  535029.305299
# 23  185853.335990
# 24  177029.445969
# 25  246916.831589
# 26  325273.837372
# 27  320058.579978
# 28  420016.755485
# 29  214066.271224
# 30   26180.339819
# 31  511784.198080
# 32  106306.897453
# 33  117058.215738
# 34  324611.813595
# 35  504337.923528
# 36  349869.553567
# 37  465858.759655
# 38  192362.302100
# 39  311678.161274
# 40  465245.904534
# 41  386984.681476
# 42  184502.646035
# 43  392037.440662
# 44  162033.393016
# 45  222621.206354
# 46  391101.577851
# 47  336830.652801
# 48  306325.246727
# 49  126055.047963
# 50  264303.195902
# 51  249667.715098
# 52  257086.306894
# 53  112782.556207
# 54  273603.118284
# 55  395662.291490
# 56  196808.259983
# 57  365664.114589
# 58  242253.640029
# 59  510177.616561
# 60  453595.864086
# 61  384708.093264
# 62  192402.827832
# 63  335722.002758
# 64  179618.804815
# 65  489539.445375
# 66  497786.243637
# 67  171935.851404
# 68  531735.321240
# 69  349065.265654
# 70  300540.019323
# 71  286261.494000
# 72  455997.894858
# 73  496615.019722
# 74  320238.571077
# 75  328386.887329
# 76  375087.305383
# 77  117138.736691
# 78  429004.452473
# 79  398571.416828
# 80  381806.509689
# 81  239495.406616
# 82  330151.895946
# 83  421253.191853
# 84  183892.537639
# 85  292692.774398
# 86  132662.135590
# 87  408844.786585
# 88  107059.898656
# 89  502922.878514
# 90  195943.637366
# 91  213591.724574
# 92  223512.575637
# 93   98659.658076
# 94  500346.121699
# 95  235235.458084
# 96  113261.596020
# 97   67930.376300
# 98  217187.560220
# 99  128854.852139

# %%
from sklearn.metrics import mean_squared_error
rss=mean_squared_error(y_test, y_pred)

# %%
print(np.sqrt(rss))
# Out:
# 8035.864039479504

# %%
plt.scatter(y_test,y_pred)
# this graph shows the strong correlation between the test values and the predicted values.
